# %% [markdown]
# # LOVE2LATE

# %% [markdown]
# ## LIBRAIRIE

# %%
# %matplotlib inline
from Homemade import project_function as fun #self made fonction

# %% [markdown]
# Création du dataframe pour L'INTERMEDIAIRE

# %%
Dataframe=fun.OCR_to_DataFrame('LTDU')

# %%
fun.store_to_folder(Dataframe)

# %%
Dataframe = fun.read_from_folder('LTDU')

# %%
fun.show_image(1658,Dataframe)
# Out:
# <PIL.Image.Image image mode=L size=1038x622 at 0x26B1A5FEA90>

# %% [markdown]
# Cleaning du dataframe, ne sera garder que les annonces.

# %%
Dataframe = fun.update_frame(Dataframe)
# Out:
# m =16
# w =14
# 0 annonces ont été perdu car le sexe n'a pas pu être extrait
# 7068 annonces ont été perdu car elles ne presentaient pas la structure type
# C:\Users\Heavy Chicken\Miniconda3\lib\site-packages\pandas\core\indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\Heavy Chicken\Miniconda3\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# 91 annonces ont été perdu faute de mot de séparation
# 58 annonces ont été perdu car l'age n'a pas pu être extrait

# %%
Dataframe.shape
# Out:
# (224, 12)

# %% [markdown]
# Le texte est converti en doc Spacy

# %% [markdown]
# Pas beaucoup d'annonce ici, y'en aurait 700 on en chope 300.

# %%
fun.store_to_folder(Dataframe, file_name = 'LTDU')
